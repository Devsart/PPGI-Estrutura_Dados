# %%
from graph import Graph

# %%
kruskal = {}
prim = {}
dijkstra = {}
for i in ['10','20','40','50']:
    grafo = Graph("dij"+i+".txt")
    kruskal[i] = grafo.kruskal()
    prim[i] = grafo.prim()
    dijkstra[i] = grafo.dijkstra('1',i)
    
    print('Resultados para as instâncias do arquivo '+"dij"+i+".txt\n")
    print('Kruskal:\n '+str(kruskal[i])+'\n\n')
    print('Prim:\n '+str(prim[i])+'\n\n')
    print('Dijkstra:\n '+str(dijkstra[i])+'\n\n')
# Out:
# Resultados para as instâncias do arquivo dij10.txt
#
# Kruskal:
#  [('4', '5'), ('9', '10'), ('6', '7'), ('1', '2'), ('5', '6'), ('3', '4'), ('8', '9'), ('6', '8'), ('2', '5')]
#
#
# Prim:
#  {('2', '3'), ('2', '5'), ('6', '7'), ('8', '9'), ('2', '4'), ('6', '8'), ('5', '6'), ('9', '10'), ('1', '2')}
#
#
# Dijkstra:
#  (deque(['1', '9', '10']), 5183.0)
#
#
# Resultados para as instâncias do arquivo dij20.txt
#
# Kruskal:
#  [('9', '10'), ('14', '15'), ('11', '12'), ('5', '6'), ('7', '8'), ('4', '7'), ('17', '20'), ('3', '4'), ('6', '9'), ('18', '20'), ('16', '19'), ('4', '9'), ('1', '2'), ('11', '14'), ('15', '17'), ('13', '14'), ('1', '3'), ('17', '19'), ('3', '18')]
#
#
# Prim:
#  {('3', '18'), ('3', '4'), ('4', '7'), ('1', '11'), ('9', '10'), ('1', '2'), ('12', '13'), ('14', '15'), ('15', '17'), ('18', '19'), ('7', '8'), ('1', '3'), ('11', '12'), ('4', '5'), ('18', '20'), ('4', '9'), ('15', '16'), ('5', '6'), ('1', '14')}
#
#
# Dijkstra:
#  (deque(['1', '20']), 3190.0)
#
#
# Resultados para as instâncias do arquivo dij40.txt
#
# Kruskal:
#  [('7', '8'), ('9', '10'), ('25', '26'), ('20', '21'), ('19', '20'), ('32', '33'), ('3', '4'), ('1', '7'), ('31', '32'), ('18', '20'), ('16', '17'), ('17', '21'), ('13', '14'), ('23', '24'), ('25', '27'), ('4', '5'), ('14', '15'), ('2', '9'), ('36', '39'), ('27', '28'), ('24', '25'), ('1', '3'), ('37', '40'), ('19', '22'), ('23', '29'), ('11', '16'), ('22', '26'), ('37', '38'), ('33', '35'), ('31', '34'), ('12', '18'), ('29', '30'), ('39', '40'), ('1', '10'), ('2', '6'), ('30', '38'), ('14', '32'), ('11', '13'), ('5', '31')]
#
#
# Prim:
#  {('1', '7'), ('33', '35'), ('3', '4'), ('6', '11'), ('1', '10'), ('5', '31'), ('31', '32'), ('27', '28'), ('1', '2'), ('14', '15'), ('14', '21'), ('32', '33'), ('24', '25'), ('29', '30'), ('37', '39'), ('21', '22'), ('31', '34'), ('4', '6'), ('7', '8'), ('6', '13'), ('30', '38'), ('25', '27'), ('14', '19'), ('1', '3'), ('25', '26'), ('35', '36'), ('11', '12'), ('4', '5'), ('30', '37'), ('14', '23'), ('1', '9'), ('23', '24'), ('14', '18'), ('14', '16'), ('16', '17'), ('14', '20'), ('38', '40'), ('6', '14'), ('23', '29')}
#
#
# Dijkstra:
#  (deque(['1', '4', '39', '40']), 8928.0)
#
#
# Resultados para as instâncias do arquivo dij50.txt
#
# Kruskal:
#  [('29', '30'), ('34', '35'), ('14', '31'), ('2', '4'), ('12', '22'), ('12', '21'), ('4', '5'), ('16', '18'), ('6', '7'), ('31', '32'), ('7', '8'), ('25', '26'), ('44', '47'), ('45', '46'), ('48', '50'), ('8', '9'), ('19', '20'), ('27', '28'), ('43', '44'), ('9', '10'), ('18', '20'), ('4', '6'), ('20', '23'), ('16', '22'), ('39', '42'), ('24', '27'), ('3', '5'), ('12', '15'), ('47', '49'), ('39', '41'), ('13', '32'), ('37', '40'), ('15', '17'), ('23', '24'), ('42', '43'), ('26', '29'), ('36', '41'), ('38', '40'), ('24', '29'), ('31', '34'), ('1', '12'), ('11', '13'), ('35', '37'), ('13', '33'), ('8', '25'), ('49', '50'), ('15', '31'), ('45', '48'), ('37', '39')]
#
#
# Prim:
#  {('12', '15'), ('35', '37'), ('6', '7'), ('12', '21'), ('1', '11'), ('39', '42'), ('31', '32'), ('27', '28'), ('9', '10'), ('44', '47'), ('1', '2'), ('43', '44'), ('34', '35'), ('47', '48'), ('32', '33'), ('15', '17'), ('17', '20'), ('42', '43'), ('49', '50'), ('24', '25'), ('2', '4'), ('29', '30'), ('37', '39'), ('31', '34'), ('4', '6'), ('1', '12'), ('24', '27'), ('7', '8'), ('15', '31'), ('37', '38'), ('47', '49'), ('8', '9'), ('25', '26'), ('13', '14'), ('35', '36'), ('4', '5'), ('12', '18'), ('12', '22'), ('11', '13'), ('37', '45'), ('20', '23'), ('2', '3'), ('23', '24'), ('37', '40'), ('15', '16'), ('24', '29'), ('17', '19'), ('45', '46'), ('39', '41')}
#
#
# Dijkstra:
#  (deque(['1', '35', '50']), 6764.0)
